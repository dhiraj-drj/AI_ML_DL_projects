# %%
import numpy as np

# %%
print("hello world")
# Out:
# hello world

# %%
def drj():
  print("Dhiraj Mandal")

# %%
print(drj())
# Out:
# Dhiraj Mandal
# None

# %%
drj()
# Out:
# Dhiraj Mandal

# %% [markdown]
# Basic Array Creation Function

# %%
arr=np.array([1,2,3,4,5])

# %%
arr
# Out:
# array([1, 2, 3, 4, 5])

# %%
print(arr)
# Out:
# [1 2 3 4 5]

# %%
print(type(arr))
# Out:
# <class 'numpy.ndarray'>
